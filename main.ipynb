# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
map1 = folium.Map(location=[13.081689, 80.269032],tiles="Stamen Toner")

# %%
df = pd.read_csv("MOCK_DATA (3).csv",
index_col='Date',parse_dates=True)
#pf.sort_index(ascending=False)

# %%
for i,j in pf.iterrows():
    folium.Marker(list((j['Lattitude'],j['Longitude']))).add_to(map1)

# %%
df[df.index.duplicated()]
df = df.loc[:,~df.columns.duplicated()]
# Out:
#                 Time  Lattitude  Longitude  Pickups
# Date
# 2022-04-04   2:58 AM  12.903408  80.222584       20
# 2022-04-01  10:03 AM  13.123774  80.199095       24
# 2022-11-17   3:18 PM  13.122809  80.196519       45
# 2022-07-22   7:12 AM  13.125770  80.235936       45
# 2022-12-03  11:01 AM  13.037418  80.242448       39
# ...              ...        ...        ...      ...
# 2022-07-15   2:51 AM  13.030521  80.237379       30
# 2022-10-30   8:55 PM  13.102567  80.236495       47
# 2022-10-19  11:07 AM  12.930861  80.196601       26
# 2023-01-13  12:07 PM  13.000741  80.239475       16
# 2022-05-11  11:27 AM  13.149456  80.203995       29
#
# [657 rows x 4 columns]

# %%
folium.Marker(location=[13.1024374787,80.2391053844]).add_to(m)

# %%
df.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
len(df)
# Out:
# 999

# %%
train = df.iloc[:800]["Pickups"]
test = df.iloc[800:]["Pickups"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train
# Out:
# Date
# 2021-03-01    14
# 2021-03-01    44
# 2021-03-01    40
# 2021-03-01    31
# 2021-03-01    21
#               ..
# 2021-03-01    50
# 2021-03-01    25
# 2021-03-01    45
# 2021-03-01    11
# 2021-03-01    41
# Name: Pickups, Length: 100, dtype: int64

# %%
train.reshape(1,-1)
scaler.fit(train,df.index)
#scaled_train = scaler.transform(train)
#scaled_test = scaler.transform(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 train.reshape(1,-1)
#       2 scaler.fit(train,df.index)
#       3 #scaled_train = scaler.transform(train)
#       4 #scaled_test = scaler.transform(test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'reshape'
